# %%
from bs4 import BeautifulSoup
import datetime
import requests
import smtplib
import time

# %%
from fake_useragent import UserAgent
ua = UserAgent()
user_agent = ua.chrome

URL = 'https://www.amazon.com/Wireless-Bluetooth-Headphones-Earphones-BMANI-VEAT00L/dp/B09FLNSYDZ/ref=sr_1_4?crid=1MFA0US23WEGT&keywords=earphones&qid=1689067973&sprefix=earphon%2Caps%2C478&sr=8-4'

headers = {"User-Agent": user_agent, "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

#page = requests.get(URL, headers=headers)

# %%
soup1 = BeautifulSoup(page.content, "html.parser")

soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

print(soup2)

#backup = soup2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 soup1 = BeautifulSoup(page.content, "html.parser")
#       3 soup2 = BeautifulSoup(soup1.prettify(), "html.parser")
#       5 print(soup2)
#
# NameError: name 'BeautifulSoup' is not defined

# %%
title = soup2.find(id="title").get_text()
price = soup2.find(class_="a-offscreen").get_text()
today = datetime.date.today()
print(price,title,today)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 title = soup2.find(id="title").get_text()
#       2 price = soup2.find(class_="a-offscreen").get_text()
#       3 today = datetime.date.today()
#
# NameError: name 'soup2' is not defined

# %%
price = price.strip()[1:]
title = title.strip()
print(title + price)
# Out:
# Wireless Earbuds Bluetooth Headphones 48hrs Play Back Sport Earphones with LED Display Over-Ear Buds with Earhooks Built-in Mic Headset for Workout Black BMANI-VEAT00L29.99

# %%
import csv

header = ["Title", "Price", "Date"]
data = [title, price, today]

#with open("Amazon_web_scraper_project.csv", "w", newline='', encoding ="UTF8") as file:
    
   # writer = csv.writer(file)
   # writer.writerow(header)
   # writer.writerow(data)

# %%
import pandas as pd 

df = pd.read_csv(r"C:\Users\burak\Amazon_web_scraper_project.csv")
df
# Out:
#                                                Title  Price        Date
# 0  Wireless Earbuds Bluetooth Headphones 48hrs Pl...  29.99  2023-07-11
# 1  Wireless Earbuds Bluetooth Headphones 48hrs Pl...  29.99  2023-07-11
# 2  Wireless Earbuds Bluetooth Headphones 48hrs Pl...  29.99  2023-07-11

# %%
#appending data to the csv
with open("Amazon_web_scraper_project.csv", "a+", newline='', encoding ="UTF8") as file:
    
    writer = csv.writer(file)
    writer.writerow(data)

# %%
df
# Out:
#                                                Title  Price        Date
# 0  Wireless Earbuds Bluetooth Headphones 48hrs Pl...  29.99  2023-07-11
# 1  Wireless Earbuds Bluetooth Headphones 48hrs Pl...  29.99  2023-07-11
# 2  Wireless Earbuds Bluetooth Headphones 48hrs Pl...  29.99  2023-07-11

# %%
from fake_useragent import UserAgent
import datetime
import csv
import requests
from bs4 import BeautifulSoup
import time

def check_price():
    while True:
        try:
            ua = UserAgent()
            user_agent = ua.chrome

            URL = 'https://www.amazon.com./Wireless-Bluetooth-Headphones-Earphones-BMANI-VEAT00L/dp/B09FLNSYDZ/ref=sr_1_4?crid=1MFA0US23WEGT&keywords=earphones&qid=1689067973&sprefix=earphon%2Caps%2C478&sr=8-4'

            headers = {"User-Agent": user_agent, "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

            page = requests.get(URL, headers=headers)

            soup1 = BeautifulSoup(page.content, "html.parser")
            soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

            title = soup2.find(id="title").get_text().strip()
            price = soup2.find(class_="a-offscreen").get_text().strip()[1:]
            today = datetime.date.today()

            header = ["Title", "Price", "Date"]
            data = [title, price, today]

            with open("Amazon_web_scraper_project.csv", "a+", newline='', encoding="UTF8") as file:
                writer = csv.writer(file)
                writer.writerow(data)

            break
        except Exception as e:
            
            print(f"An error occurred: {str(e)}")

# %%
while(True):
    check_price()
    time.sleep(86400)
# Out:
# An error occurred: 'NoneType' object has no attribute 'get_text'
# An error occurred: 'NoneType' object has no attribute 'get_text'
# An error occurred: 'NoneType' object has no attribute 'get_text'
# An error occurred: 'NoneType' object has no attribute 'get_text'
# An error occurred: 'NoneType' object has no attribute 'get_text'
# An error occurred: 'NoneType' object has no attribute 'get_text'
# An error occurred: 'NoneType' object has no attribute 'get_text'
# An error occurred: 'NoneType' object has no attribute 'get_text'
# An error occurred: 'NoneType' object has no attribute 'get_text'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[130], line 2
#       1 while(True):
# ----> 2     check_price()
#       3     time.sleep(5)
#
# Cell In[125], line 21, in check_price()
#      18 page = requests.get(URL, headers=headers)
# ...

# %%
df = pd.read_csv(r"C:\Users\burak\Amazon_web_scraper_project.csv")
df
# Out:
#                                                 Title       Price        Date
# 0   Wireless Earbuds Bluetooth Headphones 48hrs Pl...       29.99  2023-07-11
# 1   Wireless Earbuds Bluetooth Headphones 48hrs Pl...       29.99  2023-07-11
# 2   Wireless Earbuds Bluetooth Headphones 48hrs Pl...       29.99  2023-07-11
# 3   Kablosuz Kulaklık, Bluetooth Kulaklık, 48 saat...  ayfa 1 / 1  2023-07-11
# 4   Wireless Earbuds Bluetooth Headphones 48hrs Pl...       29.99  2023-07-11
# 5   Wireless Earbuds Bluetooth Headphones 48hrs Pl...       29.99  2023-07-11
# 6   Wireless Earbuds Bluetooth Headphones 48hrs Pl...       29.99  2023-07-11
# 7   Wireless Earbuds Bluetooth Headphones 48hrs Pl...       29.99  2023-07-11
# 8   Wireless Earbuds Bluetooth Headphones 48hrs Pl...       29.99  2023-07-11
# 9   Wireless Earbuds Bluetooth Headphones 48hrs Pl...       29.99  2023-07-11
# 10  Wireless Earbuds Bluetooth Headphones 48hrs Pl...       29.99  2023-07-11
# ...

# %%
def send_mail():
    server = smtplib.SMTP_SSL('smtp.gmail.com',465)
    server.ehlo()
    #server.starttls()
    server.ehlo()
    server.login('INSERT YOUR MAIL@gmail.com','xxxxxxxxxxxxxx')
    
    subject = "The Shirt you want is below $15! Now is your chance to buy!"
    body = "Alex, This is the moment we have been waiting for. Now is your chance to pick up the shirt of your dreams. Don't mess it up! Link here: https://www.amazon.com/Funny-Data-Systems-Business-Analyst/dp/B07FNW9FGJ/ref=sr_1_3?dchild=1&keywords=data+analyst+tshirt&qid=1626655184&sr=8-3"
   
    msg = f"Subject: {subject}\n\n{body}"
    
    server.sendmail(
        'INSERT YOUR MAIL@gmail.com',
        msg
